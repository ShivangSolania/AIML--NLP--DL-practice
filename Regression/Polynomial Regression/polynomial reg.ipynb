# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg1 = LinearRegression()
lin_reg1.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg1.predict(X), color = 'blue')
plt.title("exp v/s sal LINEAR")
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg2.predict(X_poly), color = 'blue')
plt.title("exp v/s sal POLY")
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %%
lin_reg1.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
lin_reg2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])

# %%
n1 = lin_reg1.predict([[6.5]])
n2 = lin_reg2.predict(poly_reg.fit_transform([[6.5]]))
print(f"Effectiveness of Linear (FAILED) = {n1[0]/1600:.2f}")
print(f"Effectiveness of Poly (PASSED) = {n2[0]/1600:.2f}")
# Out:
# Effectiveness of Linear (FAILED) = 206.49
# Effectiveness of Poly (PASSED) = 99.29
